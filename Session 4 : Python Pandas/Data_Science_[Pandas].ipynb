# %% [markdown]
# ## **Getting started with Pandas**

# %%
# I hope all of you know fundamentals of programming and basics of python

import pandas as pd

# %% [markdown]
# ## **Create Dataframes**

# %%
temp1 = ['This' , 'is' , 'a' , 'simple' , 'list' , 'for' , 'array']

temp2 = {'University' : ['Harvard', 'Princeton', 'Yale', 'Columbia', 'Cornell'], 'Rank' : [1, 2, 3, 4, 5]}

temp3 = 'https://raw.githubusercontent.com/gohil-jay/Widhya-ML-Internship/main/Week-3/clean_data.csv'

# %%
frame1 = pd.DataFrame(temp1)

#frame2 = pd.DataFrame(temp2, dtype=float)
#frame2 = pd.DataFrame(temp2, index=['rank1','rank2','rank3','rank4','rank5'])
frame2 = pd.DataFrame(temp2)

frame3 = pd.read_csv(temp3)

# %%
frame1
# Out:
#         0
# 0    This
# 1      is
# 2       a
# 3  simple
# 4    list
# 5     for
# 6   array

# %%
# print(frame2)

frame2
# Out:
#   University  Rank
# 0    Harvard     1
# 1  Princeton     2
# 2       Yale     3
# 3   Columbia     4
# 4    Cornell     5

# %%
frame3
# Out:
#     Unnamed: 0  S.No              USERNAME  ... Time since posted  Likes time
# 0            0     1         mikequindazzi  ...          11 hours    139   11
# 1            1     2       drgorillapaints  ...           2 hours     23    2
# 2            2     3    aitrading_official  ...           2 hours     25    2
# 3            3     4  opensourcedworkplace  ...           3 hours     49    3
# 4            4     5           crea.vision  ...           3 hours     30    3
# ..         ...   ...                   ...  ...               ...    ...  ...
# 95           8    19        michaelgarza__  ...           3 hours     31    3
# 96           9    21           dvlp_search  ...           3 hours     42    3
# 97          10    22            ecom.space  ...           3 hours     10    3
# 98          11    24        lb3enterprises  ...           3 hours    222    3
# 99          12    25          palmariusdev  ...           3 hours    109    3
#
# [100 rows x 9 columns]

# %% [markdown]
# ## **Manipulate DataFrames**

# %%
# Manipulate Columns

frame4 = frame3[['Followers']]

#print(frame4)
frame4
# Out:
#     Followers
# 0        1600
# 1         880
# 2         255
# 3         340
# 4         304
# ..        ...
# 95        614
# 96        450
# 97        182
# 98       2039
# 99        741
#
# [100 rows x 1 columns]

# %%
# Manipulate Rows

frame5 = pd.read_csv(temp3, index_col ="USERNAME")

row_select_1 = frame5.loc["drgorillapaints"]
print(row_select_1)

print("\n"*2)

row_select_2 = frame5.iloc[3]
print(row_select_2)

print("\n"*2)

row_select_3 = frame5.iloc[3:10]
print(row_select_3)
# Out:
# Unnamed: 0                                                           1
# S.No                                                                 2
# Caption              We all know where it’s going. We just have to ...
# Followers                                                          880
# Hashtags              #deck .#mac #macintosh#sayhello #apple #steve...
# Time since posted                                              2 hours
# Likes                                                               23
# time                                                                 2
# Name: drgorillapaints, dtype: object
#
#
#
# Unnamed: 0                                                           3
# S.No                                                                 4
# Caption                                                           sfad
# Followers                                                          340
# Hashtags             #iot #cre#workplace #CDO #bigdata #technology#...
# Time since posted                                              3 hours
# Likes                                                               49
# time                                                                 3
# Name: opensourcedworkplace, dtype: object
#
#
#
#                       Unnamed: 0  S.No  ... Likes  time
# USERNAME                                ...
# opensourcedworkplace           3     4  ...    49     3
# crea.vision                    4     5  ...    30     3
# be.masterly                    5     6  ...    18     3
# lenovoworkstations             6     7  ...    35     3
# kirellb                        7     8  ...    86     4
# ethicsandai                    8     9  ...    22     4
# diworksolucionesdeti           9    10  ...    18     7
#
# [7 rows x 8 columns]

# %%
# Manipulate column values

frame6 = pd.read_csv(temp3)

frame6['NEW1'] = frame6['Likes'] + frame6['time']
frame6['NEW2'] = frame6['Likes'] + 100
frame6['NEW3'] = frame6['Likes'] * 28


frame6
# Out:
#     Unnamed: 0  S.No              USERNAME  ... NEW1  NEW2  NEW3
# 0            0     1         mikequindazzi  ...  150   239  3892
# 1            1     2       drgorillapaints  ...   25   123   644
# 2            2     3    aitrading_official  ...   27   125   700
# 3            3     4  opensourcedworkplace  ...   52   149  1372
# 4            4     5           crea.vision  ...   33   130   840
# ..         ...   ...                   ...  ...  ...   ...   ...
# 95           8    19        michaelgarza__  ...   34   131   868
# 96           9    21           dvlp_search  ...   45   142  1176
# 97          10    22            ecom.space  ...   13   110   280
# 98          11    24        lb3enterprises  ...  225   322  6216
# 99          12    25          palmariusdev  ...  112   209  3052
#
# [100 rows x 12 columns]

# %%
# Undertsand Null Values

temp4 = frame3.isnull()

temp4
# Out:
#     Unnamed: 0   S.No  USERNAME  ...  Time since posted  Likes   time
# 0        False  False     False  ...              False  False  False
# 1        False  False     False  ...              False  False  False
# 2        False  False     False  ...              False  False  False
# 3        False  False     False  ...              False  False  False
# 4        False  False     False  ...              False  False  False
# ..         ...    ...       ...  ...                ...    ...    ...
# 95       False  False     False  ...              False  False  False
# 96       False  False     False  ...              False  False  False
# 97       False  False     False  ...              False  False  False
# 98       False  False     False  ...              False  False  False
# 99       False  False     False  ...              False  False  False
#
# [100 rows x 9 columns]

# %%
# Fill Null Values

value = 99999999

temp5 = frame3.fillna(value)

temp5
# Out:
#     Unnamed: 0  S.No              USERNAME  ... Time since posted  Likes time
# 0            0     1         mikequindazzi  ...          11 hours    139   11
# 1            1     2       drgorillapaints  ...           2 hours     23    2
# 2            2     3    aitrading_official  ...           2 hours     25    2
# 3            3     4  opensourcedworkplace  ...           3 hours     49    3
# 4            4     5           crea.vision  ...           3 hours     30    3
# ..         ...   ...                   ...  ...               ...    ...  ...
# 95           8    19        michaelgarza__  ...           3 hours     31    3
# 96           9    21           dvlp_search  ...           3 hours     42    3
# 97          10    22            ecom.space  ...           3 hours     10    3
# 98          11    24        lb3enterprises  ...           3 hours    222    3
# 99          12    25          palmariusdev  ...           3 hours    109    3
#
# [100 rows x 9 columns]

# %%
# Delete Null Values

temp6 = frame3.dropna()

temp6
# Out:
#     Unnamed: 0  S.No              USERNAME  ... Time since posted  Likes time
# 0            0     1         mikequindazzi  ...          11 hours    139   11
# 1            1     2       drgorillapaints  ...           2 hours     23    2
# 2            2     3    aitrading_official  ...           2 hours     25    2
# 3            3     4  opensourcedworkplace  ...           3 hours     49    3
# 4            4     5           crea.vision  ...           3 hours     30    3
# ..         ...   ...                   ...  ...               ...    ...  ...
# 95           8    19        michaelgarza__  ...           3 hours     31    3
# 96           9    21           dvlp_search  ...           3 hours     42    3
# 97          10    22            ecom.space  ...           3 hours     10    3
# 98          11    24        lb3enterprises  ...           3 hours    222    3
# 99          12    25          palmariusdev  ...           3 hours    109    3
#
# [94 rows x 9 columns]

# %%
# Delete particular row

temp7 = frame3.drop(2)

temp7
# Out:
#     Unnamed: 0  S.No              USERNAME  ... Time since posted  Likes time
# 0            0     1         mikequindazzi  ...          11 hours    139   11
# 1            1     2       drgorillapaints  ...           2 hours     23    2
# 3            3     4  opensourcedworkplace  ...           3 hours     49    3
# 4            4     5           crea.vision  ...           3 hours     30    3
# 5            5     6           be.masterly  ...           3 hours     18    3
# ..         ...   ...                   ...  ...               ...    ...  ...
# 95           8    19        michaelgarza__  ...           3 hours     31    3
# 96           9    21           dvlp_search  ...           3 hours     42    3
# 97          10    22            ecom.space  ...           3 hours     10    3
# 98          11    24        lb3enterprises  ...           3 hours    222    3
# 99          12    25          palmariusdev  ...           3 hours    109    3
#
# [99 rows x 9 columns]

# %%
# Add two dataframes

frame7 = frame3.append(frame3)
# frame7 = frame3[['time', 'Likes']].append(frame3[['time', 'Likes']])

frame7
# Out:
#     Unnamed: 0  S.No              USERNAME  ... Time since posted  Likes time
# 0            0     1         mikequindazzi  ...          11 hours    139   11
# 1            1     2       drgorillapaints  ...           2 hours     23    2
# 2            2     3    aitrading_official  ...           2 hours     25    2
# 3            3     4  opensourcedworkplace  ...           3 hours     49    3
# 4            4     5           crea.vision  ...           3 hours     30    3
# ..         ...   ...                   ...  ...               ...    ...  ...
# 95           8    19        michaelgarza__  ...           3 hours     31    3
# 96           9    21           dvlp_search  ...           3 hours     42    3
# 97          10    22            ecom.space  ...           3 hours     10    3
# 98          11    24        lb3enterprises  ...           3 hours    222    3
# 99          12    25          palmariusdev  ...           3 hours    109    3
#
# [200 rows x 9 columns]

# %% [markdown]
# ## **Iterate through Dataframe**

# %%
# Direct Access

temp8 = frame3['Followers'][5]

temp8
# Out:
# 1231

# %%
# Access entire column

temp10 = frame3[['USERNAME']]

temp10
# Out:
#                 USERNAME
# 0          mikequindazzi
# 1        drgorillapaints
# 2     aitrading_official
# 3   opensourcedworkplace
# 4            crea.vision
# ..                   ...
# 95        michaelgarza__
# 96           dvlp_search
# 97            ecom.space
# 98        lb3enterprises
# 99          palmariusdev
#
# [100 rows x 1 columns]

# %%
# Access entire row(s)

# temp9 = frame3.iloc[2]
temp9 = frame3.iloc[2:10]

temp9
# Out:
#    Unnamed: 0  S.No              USERNAME  ... Time since posted  Likes time
# 2           2     3    aitrading_official  ...           2 hours     25    2
# 3           3     4  opensourcedworkplace  ...           3 hours     49    3
# 4           4     5           crea.vision  ...           3 hours     30    3
# 5           5     6           be.masterly  ...           3 hours     18    3
# 6           6     7    lenovoworkstations  ...           3 hours     35    3
# 7           7     8               kirellb  ...           4 hours     86    4
# 8           8     9           ethicsandai  ...           4 hours     22    4
# 9           9    10  diworksolucionesdeti  ...           7 hours     18    7
#
# [8 rows x 9 columns]

# %% [markdown]
# # **Analyse Dataframe**

# %%
# See the top dataframe values

top = frame3.head()
#top = frame3.head(value)

top
# Out:
#    Unnamed: 0  S.No              USERNAME  ... Time since posted  Likes time
# 0           0     1         mikequindazzi  ...          11 hours    139   11
# 1           1     2       drgorillapaints  ...           2 hours     23    2
# 2           2     3    aitrading_official  ...           2 hours     25    2
# 3           3     4  opensourcedworkplace  ...           3 hours     49    3
# 4           4     5           crea.vision  ...           3 hours     30    3
#
# [5 rows x 9 columns]

# %%
# See the bottom dataframe values

bottom = frame3.tail()
#bottom = frame3.tail(value)

bottom
# Out:
#     Unnamed: 0  S.No        USERNAME  ... Time since posted  Likes time
# 95           8    19  michaelgarza__  ...           3 hours     31    3
# 96           9    21     dvlp_search  ...           3 hours     42    3
# 97          10    22      ecom.space  ...           3 hours     10    3
# 98          11    24  lb3enterprises  ...           3 hours    222    3
# 99          12    25    palmariusdev  ...           3 hours    109    3
#
# [5 rows x 9 columns]

# %%
perc_list =[.10, .20, .30, .40, .50, .60, .70, .80, .90]
types = ['object', 'float', 'int']

# desc = frame7.describe()
desc_1 = frame7.describe(percentiles = perc_list, include = types)

desc_1
# Out:
#         Unnamed: 0        S.No  ...       Likes        time
# count   200.000000  200.000000  ...  200.000000  200.000000
# unique         NaN         NaN  ...         NaN         NaN
# top            NaN         NaN  ...         NaN         NaN
# freq           NaN         NaN  ...         NaN         NaN
# mean      8.940000   16.240000  ...   46.480000    3.460000
# std       6.622362    7.365709  ...   54.948396    3.386108
# min       0.000000    1.000000  ...    8.000000    2.000000
# 10%       1.000000    6.000000  ...   11.900000    2.000000
# 20%       3.000000    9.000000  ...   17.000000    2.000000
# 30%       4.700000   11.700000  ...   20.000000    2.000000
# 40%       6.000000   14.000000  ...   24.000000    2.000000
# 50%       8.000000   16.500000  ...   29.000000    2.000000
# 60%       9.400000   18.400000  ...   31.400000    3.000000
# 70%      11.000000   21.300000  ...   42.300000    3.000000
# 80%      14.200000   23.200000  ...   50.200000    4.000000
# 90%      19.100000   26.000000  ...   95.500000    5.200000
# max      26.000000   30.000000  ...  349.000000   24.000000
#
# [17 rows x 9 columns]

# %% [markdown]
# # **Visualize DataFrame**

# %%
# Histogram

"""

temp_list = ['ggplot', 'bmh', 'dark_background', 'fivethirtyeight']

import matplotlib.pyplot as plt
plt.style.use(temp_list[1])

"""

x = frame7['time'].hist()

x

# %%
# Area Plots

y = frame3.plot.area()

y

# %%
# Bar Plots

#y_1 = frame3.plot.bar()
# y_2 = frame3['time'].plot.bar()
# y_3 = frame3.iloc[2:10].plot.bar()
y_4 = frame3.iloc[2:10].plot.bar(stacked = True)

y_4

# %%
# Line Graphs

# z_1 = frame3.plot.line()
# z_2 = frame3['Likes'].plot.line()
z_3 = frame3.iloc[2:11].plot.line()

z_3

# %%
# Scatter Plots

# w_1 = frame3.plot.scatter(x = 'Likes', y = 'time')
w_2 = frame3.plot.scatter(x = 'Likes', y = 'time', c ='Red')

w_2

# %% [markdown]
# # **Thank you!**
#
# ----
